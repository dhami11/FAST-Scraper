# %%
import pandas as pd

lhr=pd.read_csv('faculty.csv')
khi=pd.read_csv('faculty2.csv')
isb=pd.read_csv('faculty3.csv')

fast=pd.concat([lhr,khi,isb],axis=0)
fast
# Out:
#        ID                      Name          Designation  HEC_Approved  \
# 0    1238          Dr. Kashif Zafar      Professor & HOD          True
# 1    4391  Dr. Asif Mahmood Gillani            Professor          True
# 2    5424         Dr. Hammad Naveed            Professor          True
# 3    4027            Dr. Aamir Wali  Associate Professor          True
# 4    6174            Dr. Arshad Ali  Associate Professor          True
# ..    ...                       ...                  ...           ...
# 199  5354     Sehrish Hassan Shigri             Lecturer         False
# 200  5898                Sana Ilyas             Lecturer         False
# 201  5902              Zunera Malik             Lecturer         False
# 202  9341              Sadia Nauman             Lecturer         False
# 203  9529              Sumera Abbas             Lecturer         False
#
#                                  Highest_qualification  \
# 0      Ph.D(Computer Science), NUCES, Islamabad, Pa...
# ...

# %%
fast.to_csv('all_campus.csv',index=False)
fast.isnull().sum()

# %%
from ydata_profiling import ProfileReport
profile=ProfileReport(fast,title='FAST Faculty Report',)

# %%
profile.to_html('fast_report.html')
#did this on colabs seperately
# Out:
# Summarize dataset:  72%|███████▏  | 13/18 [00:00<00:00, 17.08it/s, scatter ID, ID]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/dhami/anaconda3/envs/datasci/lib/python3.9/site-packages/IPython/core/formatters.py", line 223, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/home/dhami/anaconda3/envs/datasci/lib/python3.9/site-packages/IPython/core/formatters.py", line 344, in __call__
#     return method()
#   File "/home/dhami/anaconda3/envs/datasci/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/dhami/anaconda3/envs/datasci/lib/python3.9/site-packages/ydata_profiling/profile_report.py", line 520, in _repr_html_
#     self.to_notebook_iframe()
#   File "/home/dhami/anaconda3/envs/datasci/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
# ...
